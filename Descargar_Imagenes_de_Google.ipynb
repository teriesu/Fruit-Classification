# %%
# !pip install urllib3
# !pip install selenium
# !apt-get update 
# !apt install chromium-chromedriver
# !wget http://nlp.stanford.edu/data/glove.6B.zip
# Out:
# ...
# Hit:1 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:4 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu bionic-updates InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu bionic-backports InRelease
# Hit:7 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:8 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Ign:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:10 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Ign:11 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:12 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# ...

# %%
import sys
import bs4
import requests
import os
import time
from selenium import webdriver
# Out:
# /usr/local/lib/python3.7/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.9) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
sys.path.insert(0,'/usr/lib/chromium-browser/chromedriver')

options = webdriver.ChromeOptions()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')

driver = webdriver.Chrome(options=options)
driver.get('https://www.google.com/')

# %%
#crear un directorio para guardar las imagenes
folder_name = "/content/training_data/"
if not os.path.isdir(folder_name):
   os.makedirs(folder_name)


def download_image(url, folder_name, num):

    # write image to file
    reponse = requests.get(url)
    if reponse.status_code==200:
        with open(os.path.join(folder_name, str(num)+".jpg"), 'wb') as file:
            file.write(reponse.content)


GOOGLE_IMAGE = "https://www.google.com/search?site=&tbm=isch&source=hp&biw=1873&bih=990&"

data = input('Que le gustaria Buscar ')
n_images = int(input('Cuantos Datos quiere encontrar '))


search_URL = GOOGLE_IMAGE + 'q=' + data
driver.get(search_URL)
#Scrolling all the way up
driver.execute_script("window.scrollTo(0, 0);")

page_html = driver.page_source
pageSoup = bs4.BeautifulSoup(page_html, 'html.parser')
containers = pageSoup.findAll(limit=n_images )

print(len(containers))

counter = 0

if counter <= n_images:
   len_containers = len(containers)

   for i in range(1, len_containers+1):
       if i % 25 == 0:
           continue

       xPath = """//*[@id="islrg"]/div[1]/div[%s]"""%(i)

       previewImageXPath = """//*[@id="islrg"]/div[1]/div[%s]/a[1]/div[1]/img"""%(i)
       previewImageElement = driver.find_element_by_xpath(previewImageXPath)
       previewImageURL = previewImageElement.get_attribute("src")

       driver.find_element_by_xpath(xPath).click()
          
       timeStarted = time.time()
       while True:

           imageElement = driver.find_element_by_xpath("""//*[@id="Sva75c"]/div/div/div[3]/div[2]/c-wiz/div/div[1]/div[1]/div[2]/div[1]/a/img""")
           imageURL= imageElement.get_attribute('src')

           if imageURL != previewImageURL:
               break

           else:
               #Hacer un tiempo de espera si la imagen de resolución completa no puede ser cargada
               currentTime = time.time()

               if currentTime - timeStarted > 10:
                   print("Tiempo de espera. Descargará una imagen de menor resolución y pasará a la siguiente")
                   break


         #Downloading image

       folder_name = "/content/training_data/"+ data
       if not os.path.isdir(folder_name):
           os.makedirs(folder_name)

       try:
          download_image(imageURL, folder_name, i)
          print("Descargando elemento %s de %s en total. URL: %s" % (i, len_containers + 1, imageURL))
       except:
          print("No se pudo descargar la imagen %s, continuar descargando la siguiente imagen: "%(i))

   counter+=1
# Out:
# Que le gustaria Buscar Papaya con fondo blanco
# Cuantos Datos quiere encontrar 100
# 100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:45: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:48: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:53: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
# Descargando elemento 1 de 101 en total. URL: https://thumbs.dreamstime.com/b/el-medio-corte-y-la-papaya-entera-da-fruto-en-el-fondo-blanco-66885174.jpg
# Descargando elemento 2 de 101 en total. URL: https://thumbs.dreamstime.com/b/papaya-madura-aislada-en-el-fondo-blanco-con-la-trayectoria-de-recortes-137547610.jpg
# ...

# %%
def download_image(url, folder_name, num):

    # write image to file
    reponse = requests.get(url)
    if reponse.status_code==200:
        with open(os.path.join(folder_name, str(num)+".jpg"), 'wb') as file:
            file.write(reponse.content)


GOOGLE_IMAGE1 = "https://www.google.com/search?site=&tbm=isch&source=hp&biw=1873&bih=990&"

data1 = input('Que le gustaria Buscar ')
n_images1 = int(input('Cuantos Datos quiere encontrar '))


search_URL1 = GOOGLE_IMAGE1 + 'q=' + data1
driver.get(search_URL1)

#Scrolling all the way up
driver.execute_script("window.scrollTo(0, 0);")

page_html = driver.page_source
pageSoup = bs4.BeautifulSoup(page_html, 'html.parser')
containers = pageSoup.findAll(limit=n_images1 )

print(len(containers))

counter = 0

if counter <= n_images:
   len_containers = len(containers)

   for i in range(1, len_containers+1):
       if i % 25 == 0:
           continue

       xPath = """//*[@id="islrg"]/div[1]/div[%s]"""%(i)

       previewImageXPath = """//*[@id="islrg"]/div[1]/div[%s]/a[1]/div[1]/img"""%(i)
       previewImageElement = driver.find_element_by_xpath(previewImageXPath)
       previewImageURL = previewImageElement.get_attribute("src")

       driver.find_element_by_xpath(xPath).click()
          
       timeStarted = time.time()
       while True:

           imageElement = driver.find_element_by_xpath("""//*[@id="Sva75c"]/div/div/div[3]/div[2]/c-wiz/div/div[1]/div[1]/div[2]/div[1]/a/img""")
           imageURL= imageElement.get_attribute('src')

           if imageURL != previewImageURL:
               break

           else:
               #Hacer un tiempo de espera si la imagen de resolución completa no puede ser cargada
               currentTime = time.time()

               if currentTime - timeStarted > 10:
                   print("Tiempo de espera. Descargará una imagen de menor resolución y pasará a la siguiente")
                   break


         #Downloading image

       folder_name = "/content/training_data/"+ data1
       if not os.path.isdir(folder_name):
           os.makedirs(folder_name)

       try:
          download_image(imageURL, folder_name, i)
          print("Descargando elemento %s de %s en total. URL: %s" % (i, len_containers + 1, imageURL))
       except:
          print("No se pudo descargar la imagen %s, continuar descargando la siguiente imagen: "%(i))

   counter+=1
# Out:
# Que le gustaria Buscar Papaya con fondo blanco
# Cuantos Datos quiere encontrar 100
# 100
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:40: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:43: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:48: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
# Descargando elemento 1 de 101 en total. URL: https://thumbs.dreamstime.com/b/el-medio-corte-y-la-papaya-entera-da-fruto-en-el-fondo-blanco-66885174.jpg
# Descargando elemento 2 de 101 en total. URL: https://thumbs.dreamstime.com/b/papaya-madura-aislada-en-el-fondo-blanco-con-la-trayectoria-de-recortes-137547610.jpg
# ...

# %%
# !zip -r "/content/training_data.zip" "/content/training_data"
# Out:
#   adding: content/training_data/ (stored 0%)
#   adding: content/training_data/Papaya con fondo blanco/ (stored 0%)
#   adding: content/training_data/Papaya con fondo blanco/87.jpg (deflated 3%)
#   adding: content/training_data/Papaya con fondo blanco/36.jpg (deflated 10%)
#   adding: content/training_data/Papaya con fondo blanco/86.jpg (deflated 1%)
#   adding: content/training_data/Papaya con fondo blanco/54.jpg (deflated 1%)
#   adding: content/training_data/Papaya con fondo blanco/76.jpg (deflated 6%)
#   adding: content/training_data/Papaya con fondo blanco/8.jpg (deflated 43%)
#   adding: content/training_data/Papaya con fondo blanco/83.jpg (deflated 3%)
#   adding: content/training_data/Papaya con fondo blanco/11.jpg (deflated 10%)
#   adding: content/training_data/Papaya con fondo blanco/92.jpg (deflated 4%)
#   adding: content/training_data/Papaya con fondo blanco/28.jpg (deflated 8%)
#   adding: content/training_data/Papaya con fondo blanco/48.jpg (deflated 7%)
# ...

# %%
# !rm -rf training_data/
